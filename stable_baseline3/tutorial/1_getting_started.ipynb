# %% [markdown]
# # Stable Baselines3 Tutorial - Getting Started
#
# Github repo: https://github.com/araffin/rl-tutorial-jnrr19/tree/sb3/
#
# Stable-Baselines3: https://github.com/DLR-RM/stable-baselines3
#
# Documentation: https://stable-baselines3.readthedocs.io/en/master/
#
# SB3-Contrib: https://github.com/Stable-Baselines-Team/stable-baselines3-contrib
#
# RL Baselines3 zoo: https://github.com/DLR-RM/rl-baselines3-zoo
#
# [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo) is a training framework for Reinforcement Learning (RL), using Stable Baselines3.
#
# It provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
#
# ## Introduction
#
# In this notebook, you will learn the basics for using stable baselines library: how to create a RL model, train it and evaluate it. Because all algorithms share the same interface, we will see how simple it is to switch from one algorithm to another.
#
#
# ## Install Dependencies and Stable Baselines3 Using Pip
#
# List of full dependencies can be found in the [README](https://github.com/DLR-RM/stable-baselines3).
#
#
# ```
# pip install stable-baselines3[extra]
# ```

# %%
# for autoformatting
# %load_ext jupyter_black

# %%
# !apt-get install ffmpeg freeglut3-dev xvfb  # For visualization
# !pip install "stable-baselines3[extra]>=2.0.0a4"
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# The following additional packages will be installed:
#   freeglut3 libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base
#   xfonts-encodings xfonts-utils xserver-common
# The following NEW packages will be installed:
#   freeglut3 freeglut3-dev libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils
#   xfonts-base xfonts-encodings xfonts-utils xserver-common xvfb
# 0 upgraded, 11 newly installed, 0 to remove and 13 not upgraded.
# Need to get 7,895 kB of archives.
# After this operation, 13.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 freeglut3-dev amd64 2.8.1-3 [124 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 libfontenc1 amd64 1:1.1.4-0ubuntu1 [14.0 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 libxfont2 amd64 1:2.0.3-1 [91.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 libxkbfile1 amd64 1:1.1.0-1 [65.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 x11-xkb-utils amd64 7.7+5 [158 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu1 [573 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-utils amd64 1:7.7+6 [91.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 xserver-common all 2:1.20.13-1ubuntu1~20.04.8 [27.2 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 xvfb amd64 2:1.20.13-1ubuntu1~20.04.8 [780 kB]
# Fetched 7,895 kB in 2s (3,356 kB/s)
# Selecting previously unselected package freeglut3:amd64.
# (Reading database ... 123069 files and directories currently installed.)
# Preparing to unpack .../00-freeglut3_2.8.1-3_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-3) ...
# Selecting previously unselected package freeglut3-dev:amd64.
# Preparing to unpack .../01-freeglut3-dev_2.8.1-3_amd64.deb ...
# Unpacking freeglut3-dev:amd64 (2.8.1-3) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../02-libfontenc1_1%3a1.1.4-0ubuntu1_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../03-libxfont2_1%3a2.0.3-1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.3-1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../04-libxkbfile1_1%3a1.1.0-1_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../05-x11-xkb-utils_7.7+5_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../06-xfonts-encodings_1%3a1.0.5-0ubuntu1_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu1) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../07-xfonts-utils_1%3a7.7+6_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../08-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../09-xserver-common_2%3a1.20.13-1ubuntu1~20.04.8_all.deb ...
# Unpacking xserver-common (2:1.20.13-1ubuntu1~20.04.8) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../10-xvfb_2%3a1.20.13-1ubuntu1~20.04.8_amd64.deb ...
# Unpacking xvfb (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up freeglut3:amd64 (2.8.1-3) ...
# Setting up freeglut3-dev:amd64 (2.8.1-3) ...
# Setting up libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1) ...
# Setting up libxfont2:amd64 (1:2.0.3-1) ...
# Setting up x11-xkb-utils (7.7+5) ...
# Setting up xfonts-utils (1:7.7+6) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up xserver-common (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up xvfb (2:1.20.13-1ubuntu1~20.04.8) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting stable-baselines3[extra]>=2.0.0a4
#   Downloading stable_baselines3-2.0.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.4/178.4 kB 14.3 MB/s eta 0:00:00
# Collecting gymnasium==0.28.1 (from stable-baselines3[extra]>=2.0.0a4)
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 60.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (1.22.4)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.0.1+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.7.0.72)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.12.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.65.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (13.4.2)
# Collecting shimmy[atari]~=0.2.1 (from stable-baselines3[extra]>=2.0.0a4)
#   Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (8.4.0)
# Collecting autorom[accept-rom-license]~=0.6.0 (from stable-baselines3[extra]>=2.0.0a4)
#   Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.4.0)
# Collecting jax-jumpy>=1.0.0 (from gymnasium==0.28.1->stable-baselines3[extra]>=2.0.0a4)
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->stable-baselines3[extra]>=2.0.0a4) (4.6.3)
# Collecting farama-notifications>=0.0.1 (from gymnasium==0.28.1->stable-baselines3[extra]>=2.0.0a4)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]>=2.0.0a4) (8.1.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]>=2.0.0a4) (2.27.1)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]>=2.0.0a4)
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 25.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=0.2.1->stable-baselines3[extra]>=2.0.0a4)
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 81.7 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.56.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.40.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]>=2.0.0a4) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]>=2.0.0a4) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]>=2.0.0a4) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]>=2.0.0a4) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]>=2.0.0a4) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3[extra]>=2.0.0a4) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3[extra]>=2.0.0a4) (16.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]>=2.0.0a4) (2022.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (2.14.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=0.2.1->stable-baselines3[extra]>=2.0.0a4) (5.12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a4) (0.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]>=2.0.0a4) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]>=2.0.0a4) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]>=2.0.0a4) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]>=2.0.0a4) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.2.2)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=b18bc9a1db205e4a145085fe0d7907927ff91d307cbd6852665f54e7be2b5504
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: farama-notifications, jax-jumpy, ale-py, gymnasium, AutoROM.accept-rom-license, autorom, shimmy, stable-baselines3
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 farama-notifications-0.0.4 gymnasium-0.28.1 jax-jumpy-1.0.0 shimmy-0.2.1 stable-baselines3-2.0.0

# %% [markdown]
# ## Imports

# %% [markdown]
# Stable-Baselines3 works on environments that follow the [gym interface](https://stable-baselines3.readthedocs.io/en/master/guide/custom_env.html).
# You can find a list of available environment [here](https://gymnasium.farama.org/environments/classic_control/).
#
# Not all algorithms can work with all action spaces, you can find more in this [recap table](https://stable-baselines3.readthedocs.io/en/master/guide/algos.html)

# %%
import gymnasium as gym
import numpy as np

# %% [markdown]
# The first thing you need to import is the RL model, check the documentation to know what you can use on which problem

# %%
from stable_baselines3 import PPO
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(
# /usr/local/lib/python3.10/dist-packages/jaxlib/xla_client.py:225: DeprecationWarning: ml_dtypes.float8_e4m3b11 is deprecated. Use ml_dtypes.float8_e4m3b11fnuz
#   float8_e4m3b11fnuz = ml_dtypes.float8_e4m3b11

# %% [markdown]
# The next thing you need to import is the policy class that will be used to create the networks (for the policy/value functions).
# This step is optional as you can directly use strings in the constructor:
#
# ```PPO('MlpPolicy', env)``` instead of ```PPO(MlpPolicy, env)```
#
# Note that some algorithms like `SAC` have their own `MlpPolicy`, that's why using string for the policy is the recommended option.

# %%
from stable_baselines3.ppo.policies import MlpPolicy

# %% [markdown]
# ## Create the Gym env and instantiate the agent
#
# For this example, we will use CartPole environment, a classic control problem.
#
# "A pole is attached by an un-actuated joint to a cart, which moves along a frictionless track. The system is controlled by applying a force of +1 or -1 to the cart. The pendulum starts upright, and the goal is to prevent it from falling over. A reward of +1 is provided for every timestep that the pole remains upright. "
#
# Cartpole environment: [https://gymnasium.farama.org/environments/classic_control/cart_pole/](https://gymnasium.farama.org/environments/classic_control/cart_pole/)
#
# ![Cartpole](https://cdn-images-1.medium.com/max/1143/1*h4WTQNVIsvMXJTCpXm_TAw.gif)
#
#
# We chose the MlpPolicy because the observation of the CartPole task is a feature vector, not images.
#
# The type of action to use (discrete/continuous) will be automatically deduced from the environment action space
#
# Here we are using the [Proximal Policy Optimization](https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html) algorithm, which is an Actor-Critic method: it uses a value function to improve the policy gradient descent (by reducing the variance).
#
# It combines ideas from [A2C](https://stable-baselines3.readthedocs.io/en/master/modules/a2c.html) (having multiple workers and using an entropy bonus for exploration) and [TRPO](https://stable-baselines.readthedocs.io/en/master/modules/trpo.html) (it uses a trust region to improve stability and avoid catastrophic drops in performance).
#
# PPO is an on-policy algorithm, which means that the trajectories used to update the networks must be collected using the latest policy.
# It is usually less sample efficient than off-policy alorithms like [DQN](https://stable-baselines.readthedocs.io/en/master/modules/dqn.html), [SAC](https://stable-baselines3.readthedocs.io/en/master/modules/sac.html) or [TD3](https://stable-baselines3.readthedocs.io/en/master/modules/td3.html), but is much faster regarding wall-clock time.

# %%
env = gym.make("CartPole-v1")

model = PPO(MlpPolicy, env, verbose=0)

# %% [markdown]
# We create a helper function to evaluate the agent:

# %%
from stable_baselines3.common.base_class import BaseAlgorithm


def evaluate(
    model: BaseAlgorithm,
    num_episodes: int = 100,
    deterministic: bool = True,
) -> float:
    """
    Evaluate an RL agent for `num_episodes`.

    :param model: the RL Agent
    :param env: the gym Environment
    :param num_episodes: number of episodes to evaluate it
    :param deterministic: Whether to use deterministic or stochastic actions
    :return: Mean reward for the last `num_episodes`
    """
    # This function will only work for a single environment
    vec_env = model.get_env()

    # print(f"vec_env: {vec_env}")

    obs = vec_env.reset()

    print(f"obs: {obs}")

    all_episode_rewards = []
    for _ in range(num_episodes):
        episode_rewards = []
        done = False
        # Note: SB3 VecEnv resets automatically:
        # https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api
        # obs = vec_env.reset()
        while not done:
            # _states are only useful when using LSTM policies
            # `deterministic` is to use deterministic actions
            action, _states = model.predict(obs, deterministic=deterministic)
            # here, action, rewards and dones are arrays
            # because we are using vectorized env
            obs, reward, done, _info = vec_env.step(action)
            episode_rewards.append(reward)

            print(f"obs, reward, done, _info = {obs}, {reward}, {done}, {_info}")

        all_episode_rewards.append(sum(episode_rewards))

    mean_episode_reward = np.mean(all_episode_rewards)
    print(f"Mean reward: {mean_episode_reward:.2f} - Num episodes: {num_episodes}")

    return mean_episode_reward
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Let's evaluate the un-trained agent, this should be a random agent.

# %%
# Random Agent, before training
mean_reward_before_train = evaluate(model, num_episodes=100, deterministic=True)
# Out:
# vec_env: <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f948f3f8100>
# obs: [[-0.04217225  0.04397017 -0.02686809 -0.02896506]]
# obs, reward, done, _info = [[-0.04129284  0.23946692 -0.02744739 -0.3300026 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.0365035   0.43496862 -0.03404744 -0.6312132 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02780413  0.63054866 -0.0466717  -0.9344213 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.01519316  0.8262681  -0.06536013 -1.2413971 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 1.3322026e-03  1.0221654e+00 -9.0188071e-02 -1.5538179e+00]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02177551  1.2182453  -0.12126444 -1.8732218 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.04614041  1.4144651  -0.15872887 -2.2009544 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.07442971  1.6107196  -0.20274796 -2.5381062 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01826693 -0.04487209  0.04303309 -0.02386473]], [1.], [ True], [{'episode': {'r': 9.0, 'l': 9, 't': 743.39652}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.10664411,  1.8068229 , -0.2535101 , -2.8854363 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.01736949  0.14960715  0.04255579 -0.3026657 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02036163  0.34409758  0.03650248 -0.5816296 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02724358  0.53868955  0.02486988 -0.86259377]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.03801737  0.73346424  0.00761801 -1.1473545 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.05268666  0.9284859  -0.01532908 -1.4376388 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.07125638  1.1237934  -0.04408186 -1.7350721 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.09373225  1.3193895  -0.0787833  -2.0411372 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.12012003  1.515228   -0.11960604 -2.3571222 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.1504246   1.711198   -0.16674848 -2.6840575 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.04638133 -0.04609516  0.04780964 -0.04783198]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 743.412658}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.18464856,  1.9071058 , -0.22042963, -3.0226405 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.04730323  0.1483098   0.046853   -0.3250555 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.04433703  0.3427344   0.04035189 -0.60260266]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03748235  0.5372694   0.02829984 -0.8823074 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02673696  0.7319958   0.01065369 -1.165961  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.01209704  0.92697746 -0.01266553 -1.4552847 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00644251  1.1222526  -0.04177123 -1.7518976 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02888756  1.3178229  -0.07680918 -2.0572743 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.05524402  1.5136409  -0.11795466 -2.372695  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.08551683  1.7095939  -0.16540855 -2.6991804 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03719944  0.04961491  0.02390705 -0.009404  ]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 743.427988}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.11970872,  1.9054861 , -0.21939217, -3.0374167 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.03620714  0.24438599  0.02371897 -0.29444912]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03131942  0.4391619   0.01782999 -0.5795581 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02253619  0.6340295   0.00623883 -0.8665713 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.0098556  0.829066  -0.0110926 -1.1572862]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00672572  1.0243307  -0.03423832 -1.4534265 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02721234  1.219856   -0.06330685 -1.7566066 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.05160946  1.4156357  -0.09843898 -2.0682876 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.07992217  1.6116116  -0.13980474 -2.3897226 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.11215441  1.8076576  -0.18759918 -2.7218914 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02130985  0.02186172 -0.02544153  0.03179112]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 743.443017}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.14830756,  2.0035608 , -0.24203701, -3.0654213 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.02087261 -0.17288633 -0.02480571  0.31633964]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02433034 -0.36764634 -0.01847892  0.60109764]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03168327 -0.56250495 -0.00645697  0.8879032 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.04293336 -0.7575387   0.0113011   1.1785494 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.05808414 -0.9528056   0.03487208  1.4747534 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.07714025 -1.1483358   0.06436715  1.7781209 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.10010697 -1.3441207   0.09992957  2.0901008 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.12698938 -1.5400983   0.14173159  2.4119313 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.15779135 -1.7361379   0.18997021  2.7445717 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00699803 -0.01361327 -0.02775918  0.03509384]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 743.458006}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.1925141 , -1.9320204 ,  0.24486165,  3.0886254 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.00727029 -0.20832637 -0.0270573   0.31889084]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.01143682 -0.40305272 -0.02067949  0.6029196 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.01949787 -0.5978794  -0.0086211   0.8890178 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03145546 -0.79288334  0.00915926  1.1789782 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.04731313 -0.988123    0.03273882  1.4745182 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.06707559 -1.1836294   0.06222919  1.7772442 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.09074818 -1.3793944   0.09777407  2.0886068 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.11833607 -1.5753577   0.13954622  2.4098475 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.14984322 -1.7713894   0.18774316  2.7419305 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02413942  0.04381077 -0.01835327  0.04615347]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 743.473354}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.18527101, -1.9672728 ,  0.24258177,  3.0854652 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.02501564 -0.15104327 -0.0174302   0.33298975]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02199477 -0.34591284 -0.01077041  0.6201255 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01507651 -0.5408827   0.0016321   0.90939695]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00425886 -0.7360267   0.01982004  1.2025924 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.01046168 -0.9313993   0.04387189  1.5014204 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02908966 -1.1270256   0.0739003   1.8074718 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.05163017 -1.3228902   0.11004973  2.1221735 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.07808798 -1.5189221   0.1524932   2.4467318 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.10846642 -1.714979    0.20142783  2.7820642 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.04426545  0.04402407 -0.03692997 -0.0238096 ]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 743.489178}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.142766 , -1.9108279,  0.2570691,  3.128718 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.04338497  0.23965564 -0.03740616 -0.32791182]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03859186  0.4352896  -0.04396439 -0.6321523 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02988607  0.63099647 -0.05660744 -0.9383503 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.01726614  0.826834   -0.07537445 -1.2482699 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-7.29455671e-04  1.02283704e+00 -1.00339845e-01 -1.56357872e+00]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01972729  1.2190055  -0.13161142 -1.8858018 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.0441074   1.4152906  -0.16932745 -2.2162652 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02936669 -0.02467587 -0.02640319  0.01129588]], [1.], [ True], [{'episode': {'r': 8.0, 'l': 8, 't': 743.501827}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.07241321,  1.6115793 , -0.21365276, -2.5560322 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.02887317 -0.2194094  -0.02617727  0.29553273]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02448498 -0.41414857 -0.02026662  0.5798462 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01620201 -0.6089808  -0.0086697   0.86607647]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.0040224  -0.8039836   0.00865183  1.1560209 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.01205728 -0.99921733  0.03177225  1.4514041 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03204162 -1.1947149   0.06080033  1.7538419 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.05593592 -1.3904715   0.09587717  2.0647984 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.08374535 -1.5864304   0.13717315  2.3855317 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.11547396 -1.7824676   0.18488377  2.717028  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01678849 -0.03088551  0.02944992 -0.00988115]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 743.516753}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.15112332, -1.9783727 ,  0.23922433,  3.0599241 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.01617078  0.16380198  0.02925229 -0.29312873]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01944682  0.3584949   0.02338972 -0.57644427]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02661672  0.5532813   0.01186083 -0.861668  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.03768235  0.74823976 -0.00537253 -1.150598  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.05264714  0.94343144 -0.02838449 -1.4449608 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.07151577  1.1388909  -0.05728371 -1.7463759 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.09429359  1.3346153  -0.09221122 -2.056313  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.1209859   1.5305508  -0.13333748 -2.3760395 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.1515969   1.7265767  -0.18085827 -2.7065535 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00645264 -0.03280158 -0.04559008 -0.01217974]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 743.531631}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.18612844,  1.9224869 , -0.23498935, -3.0485086 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.00579661  0.16294354 -0.04583368 -0.31889117]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00905548  0.35868728 -0.0522115  -0.6256688 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01622922  0.5544977  -0.06472488 -0.9343274 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02731918  0.7504303  -0.08341143 -1.2466267 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.04232778  0.946517   -0.10834396 -1.5642287 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.06125812  1.1427546  -0.13962853 -1.8886501 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.08411322  1.3390905  -0.17740153 -2.2212052 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02500447  0.01403685 -0.04764776 -0.00046814]], [1.], [ True], [{'episode': {'r': 8.0, 'l': 8, 't': 743.543596}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.11089502,  1.5354068 , -0.22182564, -2.562941  ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.0252852  -0.18037052 -0.04765712  0.27680883]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02167779 -0.3747813  -0.04212094  0.554088  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01418217 -0.5692873  -0.03103918  0.8332083 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00279642 -0.7639717  -0.01437502  1.1159701 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.01248301 -0.958902    0.00794439  1.4041094 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03166105 -1.1541218   0.03602657  1.6992652 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.05474349 -1.3496399   0.07001188  2.0029418 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.08173628 -1.5454187   0.11007071  2.3164573 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.11264466 -1.7413584   0.15639986  2.6408837 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.14747183 -1.9372793   0.20921753  2.9769723 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.04907976 -0.03870872  0.00738222  0.00732512]], [1.], [ True], [{'episode': {'r': 11.0, 'l': 11, 't': 743.561278}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.18621741, -2.1329017 ,  0.268757  ,  3.3250694 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.04830559 -0.23393576  0.00752872  0.30232805]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.04362687 -0.4291642   0.01357528  0.5973758 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.03504359 -0.62447345  0.0255228   0.89430374]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02255412 -0.81993204  0.04340887  1.1948991 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00615548 -1.0155884   0.06730685  1.5008652 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.01415629 -1.21146     0.09732416  1.8137808 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03838549 -1.4075216   0.13359977  2.1350496 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.06653592 -1.6036898   0.17630076  2.4658413 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03960262 -0.00845517  0.03756764 -0.04849058]], [1.], [ True], [{'episode': {'r': 9.0, 'l': 9, 't': 743.57512}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.09860972, -1.7998062 ,  0.22561759,  2.8070204 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.03977172  0.18610851  0.03659783 -0.3290879 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03604956  0.38069087  0.03001607 -0.61000866]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02843574  0.5753807   0.0178159  -0.8930884 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-1.6928123e-02  7.7025652e-01 -4.5868430e-05 -1.1801182e+00]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00152299  0.96537906 -0.02364823 -1.4728155 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01778459  1.160782   -0.05310454 -1.7727898 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.04100023  1.356461   -0.08856034 -2.0815    ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.06812945  1.5523604  -0.13019034 -2.4002004 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.09917666  1.7483572  -0.17819434 -2.7298753 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01527489 -0.01407737 -0.02255091 -0.04680635]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 743.594593}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.1341438 ,  1.9442419 , -0.23279184, -3.071162  ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.01499334  0.18136056 -0.02348704 -0.34651813]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01862055  0.37680858 -0.0304174  -0.6465139 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02615673  0.57234085 -0.04334768 -0.94861794]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.03760354  0.7680188  -0.06232004 -1.2545993 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.05296392  0.96388096 -0.08741202 -1.5661324 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.07224154  1.1599319  -0.11873467 -1.8847525 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.09544017  1.3561288  -0.15642972 -2.2118018 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.12256275  1.5523657  -0.20066576 -2.548366  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00133322 -0.00292063 -0.01535628 -0.04223634]], [1.], [ True], [{'episode': {'r': 9.0, 'l': 9, 't': 743.608297}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.15361007,  1.7484559 , -0.25163308, -2.8952    ], dtype=float32)}]
# obs, reward, done, _info = [[-0.00139164  0.19241813 -0.01620101 -0.33972448]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00245673  0.3877668  -0.0229955  -0.6374719 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01021206  0.58320177 -0.03574494 -0.93730694]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.0218761   0.778787   -0.05449108 -1.2410042 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.03745184  0.97456455 -0.07931116 -1.5502471 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.05694313  1.1705434  -0.11031611 -1.8665843 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.080354    1.3666865  -0.14764778 -2.1913776 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.10768773  1.5628953  -0.19147535 -2.5257397 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.04990119  0.02944435 -0.0394711  -0.0395184 ]], [1.], [ True], [{'episode': {'r': 9.0, 'l': 9, 't': 743.621814}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.13894564,  1.7589926 , -0.24199013, -2.8704603 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.05049007  0.22510943 -0.04026147 -0.3443889 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.05499226  0.4207803  -0.04714925 -0.6494911 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.06340787  0.61652625 -0.06013907 -0.95664036]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.07573839  0.81240314 -0.07927188 -1.2675948 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.09198646  1.0084431  -0.10462378 -1.5840129 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.11215532  1.2046424  -0.13630404 -1.9074059 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.13624817  1.4009476  -0.17445216 -2.2390819 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00932979 -0.03174848  0.02234323 -0.00455507]], [1.], [ True], [{'episode': {'r': 8.0, 'l': 8, 't': 743.633821}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.16426712,  1.5972393 , -0.21923378, -2.5800796 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.00996476  0.16304603  0.02225212 -0.29010555]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00670384  0.35784373  0.01645001 -0.5756882 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 4.5303311e-04  5.5273128e-01  4.9362490e-03 -8.6314386e-01]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01150766  0.7477857  -0.01232663 -1.1542706 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02646337  0.9430662  -0.03541204 -1.4507931 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.04532469  1.1386049  -0.0644279  -1.7543263 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.06809679  1.3343956  -0.09951442 -2.0663316 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.09478471  1.53038    -0.14084107 -2.3880627 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.1253923   1.7264315  -0.18860231 -2.7204986 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00341027  0.01746565 -0.04850788 -0.00684875]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 743.649073}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.15992093,  1.9223369 , -0.2430123 , -3.064267  ], dtype=float32)}]
# obs, reward, done, _info = [[-0.00306096  0.2132485  -0.04864486 -0.3144333 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00120401  0.40902844 -0.05493353 -0.6220518 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00938458  0.6048727  -0.06737456 -0.93151736]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02148204  0.80083597 -0.08600491 -1.2445885 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.03749876  0.9969496  -0.11089668 -1.5629259 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.05743775  1.1932094  -0.1421552  -1.888044  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.08130194  1.3895615  -0.17991608 -2.2212543 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01811075  0.031649   -0.04837066 -0.0367062 ]], [1.], [ True], [{'episode': {'r': 8.0, 'l': 8, 't': 743.661335}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.10909317,  1.5858871 , -0.22434117, -2.5635996 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.01874373  0.22743003 -0.04910479 -0.34424967]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02329233  0.42321488 -0.05598978 -0.652004  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.03175663  0.61907005 -0.06902986 -0.96177876]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.04413803  0.8150484  -0.08826543 -1.2753248 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.060439    1.0111783  -0.11377193 -1.5942906 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.08066256  1.2074512  -0.14565775 -1.9201735 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.10481159  1.4038079  -0.18406121 -2.2542617 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[0.03860698 0.04070646 0.00121942 0.01968238]], [1.], [ True], [{'episode': {'r': 8.0, 'l': 8, 't': 743.673495}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.13288775,  1.6001217 , -0.22914645, -2.5975676 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.0394211  -0.15443295  0.00161307  0.3127498 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.03633245 -0.34957784  0.00786806  0.605941  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02934089 -0.5448089   0.01998688  0.90109175]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01844471 -0.74019593  0.03800872  1.1999894 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00364079 -0.9357884   0.06200851  1.5043381 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.01507498 -1.1316055   0.09209527  1.815718  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03770709 -1.3276237   0.12840964  2.1355371 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.06425956 -1.523762    0.17112038  2.464971  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.03008722 -0.00199168 -0.04319422  0.0442352 ]], [1.], [ True], [{'episode': {'r': 9.0, 'l': 9, 't': 743.687311}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.0947348, -1.7198648,  0.2204198,  2.8048933], dtype=float32)}]
# obs, reward, done, _info = [[ 0.03004739 -0.19646849 -0.04230952  0.32298318]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02611802 -0.39096323 -0.03584985  0.6020289 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01829875 -0.58556587 -0.02380928  0.8832077 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00658744 -0.7803565  -0.00614512  1.1683116 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00901969 -0.975398    0.01722111  1.4590616 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02852765 -1.1707269   0.04640234  1.7570742 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.05194219 -1.3663428   0.08154383  2.0638196 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.07926904 -1.5621955   0.12282022  2.38057   ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.11051296 -1.7581686   0.17043161  2.7083337 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.01259668 -0.04608262 -0.03262335 -0.03433294]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 743.702548}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.14567633, -1.9540617 ,  0.22459829,  3.0477808 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.01351833  0.1494916  -0.03331    -0.33712775]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.0105285   0.34507135 -0.04005256 -0.64012593]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00362707  0.54072815 -0.05285508 -0.94514805]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00718749  0.73652065 -0.07175804 -1.253959  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.0219179   0.9324845  -0.09683722 -1.5682269 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.0405676   1.1286204  -0.12820175 -1.8894781 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.06314     1.3248808  -0.16599132 -2.219041  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02838462 -0.01406405 -0.0155201   0.03675796]], [1.], [ True], [{'episode': {'r': 8.0, 'l': 8, 't': 743.714434}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.08963762,  1.521154  , -0.21037214, -2.5579817 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.0286659  -0.20896004 -0.01478495  0.32450402]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.0328451  -0.40386838 -0.00829486  0.612488  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.04092247 -0.59887344  0.00395489  0.9025468 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.05289994 -0.7940487   0.02200583  1.1964703 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.06878091 -0.98944855  0.04593524  1.4959681 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.08856989 -1.1850979   0.0758546   1.8026328 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.11227185 -1.380981    0.11190725  2.1178925 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.13989146 -1.5770268   0.1542651   2.442954  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.171432   -1.773093    0.20312418  2.7787347 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[0.00132433 0.04324605 0.0217746  0.00344866]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 743.730321}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.20689386, -1.9689457 ,  0.25869888,  3.1257827 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.00218925 -0.1521813   0.02184357  0.3029214 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00085438 -0.34760764  0.027902    0.6024125 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00780653 -0.5431085   0.03995026  0.90375185]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.0186687  -0.73874813  0.05802529  1.2087194 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03344366 -0.93456954  0.08219968  1.519007  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.05213505 -1.1305835   0.11257982  1.8361747 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.07474673 -1.3267558   0.14930332  2.161599  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.10128184 -1.5229915   0.19253528  2.49641   ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 5.1469132e-03 -4.6024714e-02 -2.7211580e-02  5.9633454e-05]], [1.], [ True], [{'episode': {'r': 9.0, 'l': 9, 't': 743.744732}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.13174167, -1.7191181 ,  0.24246348,  2.8414202 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.00422642  0.1494767  -0.02721039 -0.30108315]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00721595  0.3449757  -0.03323205 -0.60222197]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01411547  0.54054636 -0.04527649 -0.9051844 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02492639  0.73625124 -0.06338017 -1.2117476 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.03965142  0.93213147 -0.08761513 -1.5235994 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.05829405  1.1281955  -0.11808711 -1.8422933 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.08085796  1.3244059  -0.15493298 -2.1691961 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.10734608  1.5206641  -0.1983169  -2.5054255 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.04861296 -0.02590452  0.00850232 -0.01583793]], [1.], [ True], [{'episode': {'r': 9.0, 'l': 9, 't': 743.75958}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.13775936,  1.7167926 , -0.24842541, -2.8517756 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.04913105  0.16909447  0.00818556 -0.3058262 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.04574916  0.36409882  0.00206904 -0.5959164 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03846718  0.55919176 -0.00984929 -0.8879469 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02728335  0.75444597 -0.02760823 -1.1837096 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.01219443  0.94991505 -0.05128242 -1.4849173 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00680387  1.1456233  -0.08098077 -1.7931641 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02971634  1.3415539  -0.11684405 -2.1098793 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.05654742  1.5376351  -0.15904164 -2.4362698 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.08730012  1.7337228  -0.20776702 -2.7732503 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.0268132  -0.01728973  0.01965864  0.04468518]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 743.77659}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.12197457,  1.9295819 , -0.26323205, -3.1213658 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.02646741 -0.21268798  0.02055234  0.34350517]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02221365 -0.4080962   0.02742245  0.64259756]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01405172 -0.6035894   0.0402744   0.94378835]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00197993 -0.79923016  0.05915017  1.2488489 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.01400467 -0.9950584   0.08412714  1.5594577 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03390584 -1.1910806   0.1153163   1.8771552 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.05772745 -1.387256    0.1528594   2.203292  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.08547257 -1.5834823   0.19692524  2.538965  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.0248819  -0.00450031 -0.01019839 -0.0495884 ]], [1.], [ True], [{'episode': {'r': 9.0, 'l': 9, 't': 743.792747}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.11714222, -1.7795762 ,  0.24770454,  2.8849435 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.02479189  0.19076638 -0.01119016 -0.34547147]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02860722  0.3860457  -0.01809959 -0.641662  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.03632813  0.58141524 -0.03093283 -0.9399892 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.04795644  0.77694017 -0.04973261 -1.2422291 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.06349524  0.97266394 -0.0745772  -1.5500672 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.08294852  1.1685972  -0.10557853 -1.8650556 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.10632046  1.3647051  -0.14287965 -2.188562  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.13361457  1.560892   -0.18665089 -2.5217073 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02702361 -0.04006005  0.03234515 -0.03768348]], [1.], [ True], [{'episode': {'r': 9.0, 'l': 9, 't': 743.810609}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.1648324 ,  1.7569836 , -0.23708503, -2.8652933 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.02622241  0.1545835   0.03159149 -0.31998825]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02931408  0.3492416   0.02519172 -0.6025434 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.03629892  0.5440023   0.01314085 -0.88718617]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.04717896  0.73894346 -0.00460287 -1.1757094 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.06195783  0.9341249  -0.02811706 -1.4698317 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.08064033  1.1295793  -0.05751369 -1.7711627 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.10323191  1.325301   -0.09293695 -2.0811596 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.12973794  1.5212326  -0.13456014 -2.4010727 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.16016258  1.7172484  -0.18258159 -2.73188   ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.04761978  0.00899643  0.00198854 -0.00958613]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 743.828154}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.19450755,  1.9131365 , -0.2372192 , -3.0742095 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.04743985  0.2040898   0.00179681 -0.301641  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.04335805  0.3991861  -0.00423601 -0.5937567 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03537433  0.5943671  -0.01611114 -0.88777095]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02348699  0.78970397 -0.03386656 -1.1854746 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00769291  0.9852484  -0.05757605 -1.4885781 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01201206  1.1810224  -0.08734761 -1.7986704 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.03563251  1.3770062  -0.12332102 -2.117173  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.06317263  1.5731238  -0.16566448 -2.4452798 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01498159  0.04480882 -0.02099598  0.00365377]], [1.], [ True], [{'episode': {'r': 9.0, 'l': 9, 't': 743.843672}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.09463511,  1.7692262 , -0.21457008, -2.783889  ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.01587777 -0.15000582 -0.0209229   0.28963897]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01287765 -0.34482327 -0.01513012  0.5756503 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00598119 -0.5397299  -0.00361712  0.86352867]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00481341 -0.7348024   0.01365346  1.1550721 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.01950946 -0.9300997   0.0367549   1.4520048 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03811145 -1.1256534   0.065795    1.7559407 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.06062452 -1.3214566   0.10091381  2.0683396 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.08705365 -1.5174499   0.1422806   2.3904524 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.11740265 -1.713506    0.19008964  2.7232542 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00783852 -0.00393612 -0.00730016 -0.00308112]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 743.859934}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.15167277, -1.90941   ,  0.24455473,  3.0673678 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.00791724  0.19128975 -0.00736179 -0.29805836]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00409144  0.3865159  -0.01332295 -0.59305394]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00363887  0.58182174 -0.02518403 -0.8899036 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01527531  0.7772762  -0.04298211 -1.1903956 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.03082083  0.972928   -0.06679001 -1.4962351 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.05027939  1.1687953  -0.09671472 -1.8090028 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.0736553   1.3648536  -0.13289477 -2.1301057 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.10095237  1.5610206  -0.17549689 -2.4607177 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02012295 -0.03383447 -0.01322197 -0.0183661 ]], [1.], [ True], [{'episode': {'r': 9.0, 'l': 9, 't': 743.874057}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.13217278,  1.7571392 , -0.22471124, -2.8017087 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.01944626  0.16147457 -0.01358929 -0.3151912 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02267575  0.35678744 -0.01989312 -0.61212856]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.0298115   0.55218166 -0.03213569 -0.91101015]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.04085514  0.7477234  -0.05035589 -1.2136176 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.0558096   0.9434577  -0.07462824 -1.5216452 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.07467876  1.1393979  -0.10506114 -1.8366576 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.09746671  1.3355125  -0.1417943  -2.160039  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.12417696  1.5317109  -0.18499507 -2.492931  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.01119101 -0.0274394  -0.00104772 -0.02046467]], [1.], [ True], [{'episode': {'r': 9.0, 'l': 9, 't': 743.887923}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.15481119,  1.727825  , -0.23485368, -2.8361616 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.0117398   0.16769755 -0.00145702 -0.313478  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00838585  0.36284024 -0.00772657 -0.6066201 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00112904  0.55806935 -0.01985898 -0.9017266 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01003234  0.7534547  -0.03789351 -1.2005849 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02510144  0.9490457  -0.06190521 -1.5048989 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.04408235  1.1448617  -0.09200318 -1.8162488 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.06697959  1.340879   -0.12832816 -2.1360419 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.09379716  1.5370164  -0.171049   -2.4654539 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00492771 -0.04459867  0.01366487 -0.00453688]], [1.], [ True], [{'episode': {'r': 9.0, 'l': 9, 't': 743.904127}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.12453749,  1.7331188 , -0.22035807, -2.8053584 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.00581969  0.15032467  0.01357413 -0.29287723]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00281319  0.3452505   0.00771659 -0.58124834]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00409181  0.5402635  -0.00390838 -0.8714905 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01489708  0.73543835 -0.02133819 -1.1653997 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02960585  0.93083143 -0.04464618 -1.4646955 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.04822248  1.1264709  -0.07394009 -1.7709839 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# ...
# obs, reward, done, _info = [[ 0.04150765 -0.22908361 -0.00369241  0.29854104]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.03692598 -0.42415273  0.00227841  0.59005713]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02844292 -0.6193065   0.01407955  0.8834569 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01605679 -0.8146168   0.03174869  1.1805326 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-2.3554334e-04 -1.0101362e+00  5.5359337e-02  1.4829963e+00]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02043827 -1.2058879   0.08501927  1.7924415 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.04455603 -1.4018537   0.12086809  2.110294  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.0725931  -1.5979598   0.16307397  2.4377558 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00046148 -0.03785705  0.01474964 -0.00531695]], [1.], [ True], [{'episode': {'r': 9.0, 'l': 9, 't': 744.702466}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.10455229, -1.7940598 ,  0.2118291 ,  2.7757347 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.00029566  0.1570503   0.0146433  -0.29330993]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00284535  0.35196045  0.0087771  -0.5813388 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00988456  0.5469583  -0.00284968 -0.87124395]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02082372  0.7421189  -0.02027456 -1.1648215 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.0356661   0.93749887 -0.04357098 -1.4637914 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.05441608  1.1331266  -0.07284681 -1.7697605 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.07707861  1.3289913  -0.10824202 -2.0841763 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.10365844  1.5250283  -0.14992554 -2.4082718 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.134159    1.7211031  -0.19809099 -2.742998  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03854197 -0.01332888  0.04853147  0.02267966]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 744.717467}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.16858107,  1.9169925 , -0.25295094, -3.0889444 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.03880855 -0.209112    0.04898506  0.3302712 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.04299079 -0.40489578  0.05559049  0.6379905 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.0510887  -0.60074705  0.0683503   0.94764876]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.06310365 -0.7967195   0.08730327  1.2610003 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.07903803 -0.99284273  0.11252328  1.5796994 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.09889489 -1.1891104   0.14411727  1.9052513 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.1226771  -1.3854657   0.18222229  2.2389548 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[0.03026402 0.01240309 0.01147315 0.00592382]], [1.], [ True], [{'episode': {'r': 8.0, 'l': 8, 't': 744.730468}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.15038641, -1.5817856 ,  0.22700138,  2.5818362 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.03051208 -0.1828815   0.01159162  0.30220446]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02685445 -0.37816674  0.01763571  0.5985205 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01929111 -0.573531    0.02960612  0.89670587]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.0078205  -0.7690415   0.04754024  1.198546  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00756033 -0.9647453   0.07151116  1.5057417 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02685524 -1.1606581   0.10162599  1.8198662 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.0500684  -1.356752    0.13802332  2.142316  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.07720345 -1.5529406   0.18086964  2.4742503 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.0176852  -0.01464326  0.00034565  0.00837659]], [1.], [ True], [{'episode': {'r': 9.0, 'l': 9, 't': 744.745092}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.10826226, -1.7490615 ,  0.23035465,  2.8165193 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.01739233 -0.20977016  0.00051318  0.30116856]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01319693 -0.40489942  0.00653656  0.5940133 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00509894 -0.60011226  0.01841682  0.888748  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.0069033  -0.79547924  0.03619178  1.187163  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02281289 -0.99105126  0.05993504  1.490967  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.04263391 -1.1868495   0.08975438  1.8017473 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.0663709  -1.3828526   0.12578933  2.120921  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.09402795 -1.5789831   0.16820775  2.449677  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02779024 -0.0184959  -0.04554746 -0.04898043]], [1.], [ True], [{'episode': {'r': 9.0, 'l': 9, 't': 744.759316}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.12560761, -1.7750899 ,  0.21720128,  2.7889056 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.02742033  0.17724857 -0.04652707 -0.35567895]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.0309653   0.3730001  -0.05364065 -0.6626625 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.0384253  0.5688257 -0.0668939 -0.9717412]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.04980181  0.7647785  -0.08632872 -1.2846651 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.06509738  0.9608869  -0.11202203 -1.6030815 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.08431512  1.1571423  -0.14408365 -1.9284849 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.10745797  1.353485   -0.18265335 -2.2621613 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.04751482 -0.00890853 -0.01382557  0.03018295]], [1.], [ True], [{'episode': {'r': 8.0, 'l': 8, 't': 744.772095}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.13452767,  1.5497878 , -0.22789657, -2.6051195 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.04733665 -0.20382951 -0.01322192  0.31847188]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.04326006 -0.39876068 -0.00685248  0.60695595]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.03528485 -0.5937862   0.00528664  0.8974727 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02340912 -0.78897935  0.02323609  1.1918126 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00762954 -0.98439455  0.04707235  1.491687  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.01205835 -1.1800567   0.07690609  1.7986894 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03565949 -1.3759501   0.11287988  2.1142492 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.06317849 -1.572004    0.15516487  2.4395747 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.09461857 -1.7680757   0.20395635  2.7755845 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.04049844  0.04617034  0.03300202  0.04271831]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 744.787554}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.12998009, -1.963932  ,  0.25946805,  3.1228278 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.03957503 -0.14940892  0.03385638  0.3456283 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.04256321 -0.3449957   0.04076895  0.6487922 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.04946312 -0.54066116  0.0537448   0.9540293 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.06027635 -0.73646337  0.07282538  1.2631019 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.07500561 -0.9324369   0.09808742  1.5776747 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.09365435 -1.1285812   0.1296409   1.8992683 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.11622597 -1.3248466   0.16762628  2.2292037 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.03654765 -0.00479617 -0.03358194  0.00838091]], [1.], [ True], [{'episode': {'r': 8.0, 'l': 8, 't': 744.801945}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.1427229 , -1.5211191 ,  0.21221036,  2.5685377 ], dtype=float32)}]
# obs, reward, done, _info = [[-0.03664357 -0.19942081 -0.03341432  0.29028204]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.04063198 -0.39405078 -0.02760868  0.572242  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.048513   -0.5887749  -0.01616384  0.85610104]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-6.0288500e-02 -7.8367293e-01  9.5818343e-04  1.1436579e+00]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.07596195 -0.9788074   0.02383134  1.4366412 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.0955381  -1.1742148   0.05256417  1.7366749 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.11902241 -1.3698952   0.08729766  2.0452368 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.1464203 -1.565798   0.1282024  2.3636048]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.17773627 -1.7618072   0.1754745   2.692794  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01563231 -0.0045197  -0.02873112 -0.00702631]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 744.81805}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.21297242, -1.9577224 ,  0.22933038,  3.0334795 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.01554192  0.19100226 -0.02887165 -0.308634  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01936196  0.38652346 -0.03504433 -0.61028063]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02709243  0.58211726 -0.04724994 -0.91379213]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.03873478  0.77784544 -0.06552579 -1.220943  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.05429168  0.97374773 -0.08994465 -1.5334166 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.07376664  1.1698308  -0.12061298 -1.8527606 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.09716326  1.366055   -0.15766819 -2.1803327 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.12448436  1.5623186  -0.20127484 -2.517239  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02891593 -0.02853494  0.04314545 -0.02485126]], [1.], [ True], [{'episode': {'r': 9.0, 'l': 9, 't': 744.832202}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.15573072,  1.7584404 , -0.25161964, -2.864259  ], dtype=float32)}]
# obs, reward, done, _info = [[-0.02948663  0.16594256  0.04264842 -0.3036152 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02616778  0.36043158  0.03657612 -0.5825486 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.01895914  0.55502254  0.02492515 -0.8634888 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00785869  0.74979645  0.00765537 -1.1482317 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00713723  0.9448176  -0.01530926 -1.4385042 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02603359  1.1401248  -0.04407935 -1.7359315 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.04883608  1.3357208  -0.07879797 -2.0419955 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.0755505   1.5315591  -0.11963788 -2.3579843 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.10618168  1.7275288  -0.16679758 -2.6849272 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02887491  0.00902759 -0.01525658  0.017069  ]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 744.856346}, 'TimeLimit.truncated': False, 'terminal_observation': array([ 0.14073226,  1.923436  , -0.22049612, -3.0235212 ], dtype=float32)}]
# obs, reward, done, _info = [[ 0.02905546 -0.18587227 -0.0149152   0.3048995 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.02533802 -0.38077852 -0.00881721  0.5928415 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.01772245 -0.575776    0.00303962  0.882734  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00620693 -0.77093905  0.0206943   1.176371  ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.00921185 -0.9663237   0.04422172  1.4754688 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.02853833 -1.1619571   0.07373109  1.7816291 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.05177747 -1.3578267   0.10936368  2.0962925 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.07893401 -1.5538658   0.15128954  2.4206834 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[-0.11001132 -1.749937    0.1997032   2.7557404 ]], [1.], [False], [{'TimeLimit.truncated': False}]
# obs, reward, done, _info = [[ 0.00645149 -0.04135416 -0.0260871  -0.02780436]], [1.], [ True], [{'episode': {'r': 10.0, 'l': 10, 't': 744.872263}, 'TimeLimit.truncated': False, 'terminal_observation': array([-0.14501007, -1.9458138 ,  0.254818  ,  3.102039  ], dtype=float32)}]
# Mean reward: 9.15 - Num episodes: 100

# %% [markdown]
# Stable-Baselines already provides you with that helper:

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100, warn=False)

print(f"mean_reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward: 9.14 +/- 0.71

# %% [markdown]
# ## Train the agent and evaluate it

# %%
# Train the agent for 10000 steps
model.learn(total_timesteps=10_000)

# %%
# Evaluate the trained agent
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100)

print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward:328.51 +/- 134.16

# %% [markdown]
# Apparently the training went well, the mean reward increased a lot !

# %% [markdown]
# ### Prepare video recording

# %%
# Set up fake display; otherwise rendering will fail
import os
os.system("Xvfb :1 -screen 0 1024x768x24 &")
os.environ['DISPLAY'] = ':1'

# %%
import base64
from pathlib import Path

from IPython import display as ipythondisplay


def show_videos(video_path="", prefix=""):
    """
    Taken from https://github.com/eleurent/highway-env

    :param video_path: (str) Path to the folder containing videos
    :param prefix: (str) Filter the video, showing only the only starting with this prefix
    """
    html = []
    for mp4 in Path(video_path).glob("{}*.mp4".format(prefix)):
        video_b64 = base64.b64encode(mp4.read_bytes())
        html.append(
            """<video alt="{}" autoplay
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{}" type="video/mp4" />
                </video>""".format(
                mp4, video_b64.decode("ascii")
            )
        )
    ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))

# %% [markdown]
# We will record a video using the [VecVideoRecorder](https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecvideorecorder) wrapper, you will learn about those wrapper in the next notebook.

# %%
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv


def record_video(env_id, model, video_length=500, prefix="", video_folder="videos/"):
    """
    :param env_id: (str)
    :param model: (RL model)
    :param video_length: (int)
    :param prefix: (str)
    :param video_folder: (str)
    """
    eval_env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])
    # Start the video at step=0 and record 500 steps
    eval_env = VecVideoRecorder(
        eval_env,
        video_folder=video_folder,
        record_video_trigger=lambda step: step == 0,
        video_length=video_length,
        name_prefix=prefix,
    )

    obs = eval_env.reset()
    for _ in range(video_length):
        action, _ = model.predict(obs)
        obs, _, _, _ = eval_env.step(action)

    # Close the video recorder
    eval_env.close()

# %% [markdown]
# ### Visualize trained agent

# %%
record_video("CartPole-v1", model, video_length=500, prefix="ppo-cartpole")
# Out:
# Saving video to /content/videos/ppo-cartpole-step-0-to-step-500.mp4
# Moviepy - Building video /content/videos/ppo-cartpole-step-0-to-step-500.mp4.
# Moviepy - Writing video /content/videos/ppo-cartpole-step-0-to-step-500.mp4
# Moviepy - Done !
# Moviepy - video ready /content/videos/ppo-cartpole-step-0-to-step-500.mp4

# %%
show_videos("videos", prefix="ppo")
# Out:
# <video alt="videos/ppo-cartpole-step-0-to-step-500.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>

# %% [markdown]
# ## Bonus: Train a RL Model in One Line
#
# The policy class to use will be inferred and the environment will be automatically created. This works because both are [registered](https://stable-baselines3.readthedocs.io/en/master/guide/quickstart.html).

# %%
model = PPO('MlpPolicy', "CartPole-v1", verbose=1).learn(1000)
# Out:
# Using cuda device
# Creating environment from the given name 'CartPole-v1'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.9     |
# |    ep_rew_mean     | 22.9     |
# | time/              |          |
# |    fps             | 780      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------

# %% [markdown]
# ## Conclusion
#
# In this notebook we have seen:
# - how to define and train a RL model using stable baselines3, it takes only one line of code ;)
